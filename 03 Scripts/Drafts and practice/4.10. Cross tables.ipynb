# %%
#Importing libraries

import pandas as pd
import numpy as np
import os

# %%
#Import the dataframe 'customers'
#Create a path

path = r'/Users/alexbor/Desktop/Data Analytics/Immersion/Submissions/Instacart Basket Analysis'

#Import the df 

ords_prods_cust_merge = pd.read_pickle(os.path.join(path, '02 Data ', 'Prepared data', 'ords_prods_cust_merge.pkl'))

# %%
#Create a cross table for 'days_since_prior_order' and 'order_number'

crosstab = pd.crosstab(ords_prods_cust_merge['days_since_prior_order'], ords_prods_cust_merge['order_number'], dropna = False)

# %%
#Save the cross table to clipboard

crosstab.to_clipboard()

# %%
ords_prods_cust_merge.head()
# Out:
#   user_id First Name Last Name  Gender     STATE  Age date_joined  \
# 0   26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 1   26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 2   26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 3   26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 4   26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
#
#    Number of dependants fam_status  income  ...    price_range_loc  \
# 0                     3    married  165665  ...  Mid-range product
# 1                     3    married  165665  ...  Mid-range product
# 2                     3    married  165665  ...  Mid-range product
# 3                     3    married  165665  ...  Low-range product
# 4                     3    married  165665  ...  Low-range product
#
#       busiest day  busiest_period_of_day  max_order  loyalty_flag  \
# 0     Busiest day            Most orders          8  New customer
# ...
