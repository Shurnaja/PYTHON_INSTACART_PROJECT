# %% [markdown]
# # Here I conducted analysis and created visualizations of additional questions from the project brief that were not covered in the exercises

# %% [markdown]
# # Contents
#
# ### 1. Spender type and brand loyalty
# ### 2. Brand loyalty by regions
# ### 3. Spender types by regions¶
# ### 4. Department popularity
# ### 5. User activity¶
# ### 6. Brand loyalty and user activity¶
# ### 7. Brand loyalty and price ranges
# ### 8. User activity by regions
# ### 9. User activity and department popularity
# ### 10. Customer age and department popularity (updated from Task 4.10._AlexBorschke)

# %%
#Panda libraries 

import pandas as pd
import numpy as np
import os

#Viz libraries 

import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# %%
#Importing the dataset 

path = r'/Users/alexbor/Desktop/Data Analytics/Immersion/Submissions/Instacart Basket Analysis'

ords_prods_cust_merge = pd.read_pickle(os.path.join(path, '02 Data ', 'Prepared data', 'ords_prods_cust_merge_4.10.pkl'))

# %% [markdown]
# # 1. Spender type and brand loyalty

# %%
#Create a cross table to see loyalty groups and spender type relationshiop

crosstab_loyalty_spender = pd.crosstab(ords_prods_cust_merge['spender_type'], ords_prods_cust_merge['loyalty_flag'], dropna = False)

# %%
#Create a viz loyalty groups and spender type

spender_loyalty_bar = crosstab_loyalty_spender.plot.bar(colormap = 'tab20',
                                                   figsize = (12, 8)) 
plt.title('Spender type by brand loyalty')
plt.legend(loc = 'lower right', ncol = 2)
plt.xlabel('')
plt.xticks(rotation = 90)
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#Export the viz 

spender_loyalty_bar.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'spender_loyalty_bar.png'))

# %% [markdown]
# # 2. Brand loyalty by regions

# %%
#Relationship between regions and ordering habits 

loyalty_region = pd.crosstab(ords_prods_cust_merge['Region'], ords_prods_cust_merge['loyalty_flag'], dropna = False)

# %%
#Create a viz loyalty groups and regions 

region_loyalty_bar = loyalty_region.plot.bar(colormap = 'winter',
                                                   figsize = (12, 8)) 
plt.title('Brand loyalty by regions')
plt.legend(loc = 'lower right', ncol = 2)
plt.xlabel('')
plt.xticks(rotation = 90)
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#Export the viz 

region_loyalty_bar.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'region_loyalty_bar.png'))

# %% [markdown]
# # 3. Spender types by regions

# %%
#Relationship between regions and spender types 

spender_region = pd.crosstab(ords_prods_cust_merge['Region'], ords_prods_cust_merge['spender_type'], dropna = False)

# %%
spender_region_bar = spender_region.plot.bar(colormap = 'summer',
                                                   figsize = (12, 8)) 
plt.title('Spender types by regions')
plt.legend(loc = 'lower right', ncol = 2)
plt.xlabel('')
plt.xticks(rotation = 90)
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#Export the viz 

spender_region_bar.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'spender_region_bar.png'))

# %% [markdown]
# # 4. Department popularity

# %%
#Product popularity in general 

pop_dep = ords_prods_cust_merge['department'].value_counts().plot.bar(color = ['green', 'yellow', 'orange','blue'])

plt.ylabel('Frequency')
plt.title('Products popularity',fontsize=12)
plt.show()

# %%
#Export the viz 

pop_dep.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'pop_dep.png'))

# %% [markdown]
# # 5. User activity

# %%
#User activity viz 

user_activity_bar = ords_prods_cust_merge['user_activity'].value_counts().plot.bar(color = ['pink', 'red', 'orange'])

plt.ylabel('Frequency')
plt.title('User activity',fontsize=12)
plt.show()

# %% [markdown]
# # 6. Brand loyalty and user activity

# %%
#crosstab between brand loyalty and user activity 

user_act_loyalty = pd.crosstab(ords_prods_cust_merge['user_activity'], ords_prods_cust_merge['loyalty_flag'], dropna = False)

# %%
#viz of the crosstab brand loyalty and user activity 

user_act_loyalty_bar = user_act_loyalty.plot.bar(colormap = 'autumn',
                                                   figsize = (12, 8)) 
plt.title('Brand loyalty by user activity')
plt.legend(loc = 'lower right', ncol = 2)
plt.xlabel('')
plt.xticks(rotation = 90)
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#Export the viz 

user_act_loyalty_bar.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'user_act_loyalty_bar.png'))

# %% [markdown]
# # 7. Brand loyalty and price ranges

# %%
#Crosstab brand loyalty and price ranges 

prices_brand_loyalty = pd.crosstab(ords_prods_cust_merge['price_range_loc'], ords_prods_cust_merge['loyalty_flag'], dropna = False)

# %%
#viz of the crosstab brand loyalty and price ranges 

prices_loyalty_bar = prices_brand_loyalty.plot.bar(colormap = 'autumn',
                                                   figsize = (12, 8)) 
plt.title('Brand loyalty by price ranges')
plt.legend(loc = 'lower right', ncol = 2)
plt.xlabel('')
plt.xticks(rotation = 90)
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#Export the viz 

prices_loyalty_bar.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'prices_loyalty_bar.png'))

# %% [markdown]
# # 8. User activity by regions

# %%
#Crosstab user activity and regions

activity_regions = pd.crosstab(ords_prods_cust_merge['user_activity'], ords_prods_cust_merge['Region'], dropna = False)

# %%
activity_regions_bar = activity_regions.plot.bar(colormap = 'summer',
                                                   figsize = (12, 8)) 
plt.title('User activity by regions')
plt.legend(loc = 'lower right', ncol = 2)
plt.xlabel('')
plt.xticks(rotation = 90)
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#Export the viz 

activity_regions_bar.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'activity_regions_bar.png'))

# %% [markdown]
# # 9. User activity and department popularity

# %%
#Cross tab departments and user activity 

dep_activity = pd.crosstab(ords_prods_cust_merge['department'], ords_prods_cust_merge['user_activity'], dropna = False)

# %%
dep_activity
# Out:
# user_activity    Frequent customer  Non-frequent customer  Regular customer
# department
# alcohol                     100491                  13271             30865
# babies                      316214                  25297             68881
# bakery                      770435                 103019            247374
# beverages                  1756158                 244136            571607
# breakfast                   455837                  64106            150907
# bulk                         25087                   2514              5850
# canned goods                658729                 108011            245334
# dairy eggs                 3623889                 452920           1100373
# deli                        674588                  98098            231148
# dry goods pasta             534052                  87959            200125
# frozen                     1368221                 228335            525175
# ...

# %%
dep_activity_bar = dep_activity.plot.bar(colormap = 'winter',
                                                   figsize = (12, 8)) 
plt.title('Departments and user activity')
plt.legend(loc = 'lower right', ncol = 2)
plt.xlabel('')
plt.xticks(rotation = 90)
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#Export the viz 

dep_activity_bar.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'dep_activity_bar.png'))

# %% [markdown]
# # 10. Customer age and department popularity (updated from Task 4.10._AlexBorschke)

# %%
#Create a cross table to see the relationship between customer age groups and departments. 

crosstab_age_dep = pd.crosstab(ords_prods_cust_merge['department'], ords_prods_cust_merge['Customer age group'], dropna = False)

# %%
#Create a viz for age group purchases across deparments 

age_dep_bar = crosstab_age_dep.plot.bar(colormap = 'tab20',
                                                   figsize = (12, 8)) 
plt.title('Purchases made my customer age groups by departments')
plt.legend(loc = 'lower right', ncol = 2)
plt.xlabel('Department')
plt.xticks(rotation = 90)
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#Export viz age groups across departments  

age_dep_bar.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'age_dep_bar.png'))
